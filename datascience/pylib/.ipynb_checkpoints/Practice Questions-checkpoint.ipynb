# %%
import numpy as np
import pandas as pd

# %%
#Create a NumPy array with elements [10,20,30,40,50]
ar=np.array([10,20,30,40,50])
print(ar)
# Out:
# [10 20 30 40 50]

# %%
#Create a NumPy array off all zeros of size 5.
ar1=np.zeros(5)
print(ar1)
# Out:
# [0. 0. 0. 0. 0.]

# %%
#Create a NumPy array off all ones of shape (3,3)
ar2=np.ones((3,3))
print(ar2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 #Create a NumPy array off all ones of shape (3,3)
# ----> 2 ar2=np.ones(3,3)
#       3 print(ar2)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\numpy\_core\numeric.py:232, in ones(shape, dtype, order, device, like)
#     227 if like is not None:
#     228     return _ones_with_like(
#     229         like, shape, dtype=dtype, order=order, device=device
#     230     )
# --> 232 a = empty(shape, dtype, order, device=device)
#     233 multiarray.copyto(a, 1, casting='unsafe')
#     234 return a
#
# TypeError: Cannot interpret '3' as a data type
