# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('Employee_data.csv')
print(df)
# Out:
#     ID    Name  Age  Gender  Department  Salary  Experience       City  \
# 0    1    Amit   25    Male          IT   50000           2      Delhi
# 1    2    Neha   30  Female          HR   60000           5     Mumbai
# 2    3    Ravi   35    Male     Finance   75000           8  Bangalore
# 3    4   Pooja   28  Female          IT   52000           3      Delhi
# 4    5   Ankit   40    Male  Management   90000          12  Hyderabad
# 5    6   Sneha   27  Female          HR   58000           4       Pune
# 6    7   Rahul   32    Male     Finance   72000           7    Chennai
# 7    8  Kavita   29  Female          IT   54000           3      Delhi
# 8    9   Arjun   45    Male  Management   95000          15     Mumbai
# 9   10   Meena   26  Female          HR   57000           2    Kolkata
# 10  11   Varun   31    Male     Finance   70000           6      Delhi
# 11  12  Ritika   33  Female          IT   65000           7  Bangalore
# ...

# %%
df.head()
# Out:
#    ID   Name  Age  Gender  Department  Salary  Experience       City  \
# 0   1   Amit   25    Male          IT   50000           2      Delhi
# 1   2   Neha   30  Female          HR   60000           5     Mumbai
# 2   3   Ravi   35    Male     Finance   75000           8  Bangalore
# 3   4  Pooja   28  Female          IT   52000           3      Delhi
# 4   5  Ankit   40    Male  Management   90000          12  Hyderabad
#
#    Joining_Year  Performance_Score
# 0          2022                  3
# 1          2019                  4
# 2          2016                  5
# 3          2021                  3
# 4          2012                  5

# %%
df.shape
# Out:
# (25, 10)

# %%
df.dtypes
# Out:
# ID                    int64
# Name                 object
# Age                   int64
# Gender               object
# Department           object
# Salary                int64
# Experience            int64
# City                 object
# Joining_Year          int64
# Performance_Score     int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# ID                   0
# Name                 0
# Age                  0
# Gender               0
# Department           0
# Salary               0
# Experience           0
# City                 0
# Joining_Year         0
# Performance_Score    0
# dtype: int64

# %%
df.describe()
# Out:
#               ID        Age        Salary  Experience  Joining_Year  \
# count  25.000000  25.000000     25.000000   25.000000     25.000000
# mean   13.000000  32.440000  68720.000000    6.680000   2017.360000
# std     7.359801   5.972716  15263.027223    4.150502      4.071036
# min     1.000000  24.000000  50000.000000    1.000000   2010.000000
# 25%     7.000000  28.000000  55000.000000    3.000000   2014.000000
# 50%    13.000000  31.000000  65000.000000    6.000000   2018.000000
# 75%    19.000000  37.000000  78000.000000   10.000000   2021.000000
# max    25.000000  45.000000  95000.000000   15.000000   2023.000000
#
#        Performance_Score
# count          25.000000
# mean            4.000000
# std             0.866025
# min             3.000000
# 25%             3.000000
# 50%             4.000000
# 75%             5.000000
# max             5.000000

# %%
no_of_employees=df.Department.value_counts()
print(no_of_employees)
df.Department.value_counts().nlargest(5).plot(kind='bar')
plt.title('Numbers of Employees')
plt.xlabel('Department')
plt.ylabel('numbers of Emplyees')
plt.show()
# Out:
# Department
# IT            7
# HR            6
# Finance       6
# Management    6
# Name: count, dtype: int64

# %%
print(df['Salary'].mean())
# Out:
# 68720.0

# %%
print(df['Salary'].max())
print(df['Salary'].min())
# Out:
# 95000
# 50000

# %%
print(df.groupby('Department')['Salary'].mean().round(2))
# Out:
# Department
# Finance       74166.67
# HR            56666.67
# IT            55285.71
# Management    91000.00
# Name: Salary, dtype: float64

# %%
df.City.value_counts().plot(kind='bar')
plt.title('Numbers of Employees')
plt.xlabel('City')
plt.ylabel('numbers of Emplyees')
plt.show()

# %%
df[df['Salary']>70000]
# Out:
#     ID    Name  Age  Gender  Department  Salary  Experience       City  \
# 2    3    Ravi   35    Male     Finance   75000           8  Bangalore
# 4    5   Ankit   40    Male  Management   90000          12  Hyderabad
# 6    7   Rahul   32    Male     Finance   72000           7    Chennai
# 8    9   Arjun   45    Male  Management   95000          15     Mumbai
# 12  13  Deepak   38    Male  Management   88000          10  Hyderabad
# 15  16   Nisha   36  Female     Finance   78000           9     Mumbai
# 16  17   Karan   41    Male  Management   92000          13    Chennai
# 18  19  Manish   34    Male     Finance   74000           8  Bangalore
# 20  21   Rohit   37    Male  Management   87000          11  Hyderabad
# 22  23  Ashish   39    Male     Finance   76000          10     Mumbai
# 24  25   Vikas   42    Male  Management   94000          14    Chennai
#
#     Joining_Year  Performance_Score
# 2           2016                  5
# 4           2012                  5
# ...

# %%
df[df['Experience']>5]
# Out:
#     ID    Name  Age  Gender  Department  Salary  Experience       City  \
# 2    3    Ravi   35    Male     Finance   75000           8  Bangalore
# 4    5   Ankit   40    Male  Management   90000          12  Hyderabad
# 6    7   Rahul   32    Male     Finance   72000           7    Chennai
# 8    9   Arjun   45    Male  Management   95000          15     Mumbai
# 10  11   Varun   31    Male     Finance   70000           6      Delhi
# 11  12  Ritika   33  Female          IT   65000           7  Bangalore
# 12  13  Deepak   38    Male  Management   88000          10  Hyderabad
# 15  16   Nisha   36  Female     Finance   78000           9     Mumbai
# 16  17   Karan   41    Male  Management   92000          13    Chennai
# 18  19  Manish   34    Male     Finance   74000           8  Bangalore
# 20  21   Rohit   37    Male  Management   87000          11  Hyderabad
# 22  23  Ashish   39    Male     Finance   76000          10     Mumbai
# ...

# %%
#highest_salary_employee
res=df[df['Salary']==df['Salary'].max()]
res
# Out:
#    ID   Name  Age Gender  Department  Salary  Experience    City  \
# 8   9  Arjun   45   Male  Management   95000          15  Mumbai
#
#    Joining_Year  Performance_Score
# 8          2010                  5

# %%
df.Department.value_counts().plot(kind='bar')
plt.title('Numbers of emplyee')
plt.xlabel('department')
plt.ylabel('numbers of employee')
plt.show()

# %%
plt.scatter(df['Experience'],df['Salary'])
plt.xlabel('Experience')
plt.ylabel('Salary')
plt.title('Relation b/w Experience vs Salary')
plt.show()

# %%
sns.boxplot(x='Salary',y='Department',data=df)
# Out:
# <Axes: xlabel='Salary', ylabel='Department'>
